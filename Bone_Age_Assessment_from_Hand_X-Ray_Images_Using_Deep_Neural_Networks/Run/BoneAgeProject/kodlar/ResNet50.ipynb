# %%
# ===============================
# 1. ORTAM & DRIVE AYARLARI
# ===============================

# Temel kütüphaneler
import os
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt

# TensorFlow / Keras
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input

# Colab Drive
from google.colab import drive

# -------------------------------
# Google Drive bağla
# -------------------------------
drive.mount('/content/drive')

# -------------------------------
# Proje yolları
# -------------------------------
PROJECT_ROOT = "/content/drive/My Drive/BoneAgeProject"
DATASET_DIR  = os.path.join(PROJECT_ROOT, "DATASET")
MODEL_DIR    = os.path.join(PROJECT_ROOT, "models")

# -------------------------------
# Dataset alt klasörleri
# -------------------------------
Articular_Surface_Train = os.path.join(DATASET_DIR, "Articular_Surface_Train")
Articular_Surface_Val   = os.path.join(DATASET_DIR, "Articular_Surface_Val")

Epiphysis_Train = os.path.join(DATASET_DIR, "Epiphysis_Train")
Epiphysis_Val   = os.path.join(DATASET_DIR, "Epiphysis_Val")

train_csv = os.path.join(DATASET_DIR, "train.csv")
val_csv   = os.path.join(DATASET_DIR, "val.csv")

# -------------------------------
# Global sabitler
# -------------------------------
IMG_SIZE   = 320
BATCH_SIZE = 8
MAX_AGE    = 228

# -------------------------------
# Ortam bilgisi (kontrol amaçlı)
# -------------------------------
print("TensorFlow:", tf.__version__)
print("GPU:", tf.config.list_physical_devices("GPU"))
print("Proje dizini:", PROJECT_ROOT)
print("Dataset dizini:", DATASET_DIR)
print("Model kayıt dizini:", MODEL_DIR)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# TensorFlow: 2.19.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Proje dizini: /content/drive/My Drive/BoneAgeProject
# Dataset dizini: /content/drive/My Drive/BoneAgeProject/DATASET
# Model kayıt dizini: /content/drive/My Drive/BoneAgeProject/models

# %%
# ===============================
# 2. VERİ YÜKLEME & tf.data
# ===============================

def load_image(path):
    img = cv2.imread(path)
    if img is None:
        return None
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
    img = img.astype(np.float32)
    return img


def create_dataset(csv_path, art_dir, epi_dir):
    df = pd.read_csv(csv_path)

    X_art, X_epi, males, y = [], [], [], []

    for _, row in df.iterrows():
        _id = str(row["id"])
        boneage = float(row["boneage"])

        art_path = os.path.join(art_dir, _id + ".png")
        epi_path = os.path.join(epi_dir, _id + ".png")

        if not (os.path.exists(art_path) and os.path.exists(epi_path)):
            continue

        img_art = load_image(art_path)
        img_epi = load_image(epi_path)

        if img_art is None or img_epi is None:
          continue

        X_art.append(img_art)
        X_epi.append(img_epi)
        males.append(1.0 if row["male"] else 0.0)
        y.append(boneage)

    return (
        np.array(X_art, dtype=np.float32),
        np.array(X_epi, dtype=np.float32),
        np.array(males, dtype=np.float32).reshape(-1, 1),
        np.array(y, dtype=np.float32),
    )


# -------------------------------
# Datasetleri yükle
# -------------------------------
X_art_train, X_epi_train, male_train, y_train = create_dataset(
    train_csv, Articular_Surface_Train, Epiphysis_Train
)

X_art_val, X_epi_val, male_val, y_val = create_dataset(
    val_csv, Articular_Surface_Val, Epiphysis_Val
)

print("Veriler yüklendi.")

# -------------------------------
# tf.data Datasetleri
# -------------------------------
train_ds = tf.data.Dataset.from_tensor_slices(
    (
        {
            "art_input": X_art_train,
            "epi_input": X_epi_train,
            "male_input": male_train,
        },
        y_train,
    )
)

val_ds = tf.data.Dataset.from_tensor_slices(
    (
        {
            "art_input": X_art_val,
            "epi_input": X_epi_val,
            "male_input": male_val,
        },
        y_val,
    )
)

train_ds = train_ds.shuffle(1000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
val_ds   = val_ds.shuffle(100).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

print("tf.data pipeline hazır.")
# Out:
# Veriler yüklendi.
# tf.data pipeline hazır.

# %%
# ===============================
# 3. MODEL TANIMI
# ===============================

# --- EfficientNet Backbone ---
def build_backbone(name):
    inp = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = preprocess_input(inp)

    base = ResNet50(
      include_top=False,
      weights="imagenet",
      pooling="avg"
    )


    # 1) Tüm katmanları dondur
    for layer in base.layers:
        layer.trainable = True

    # 2) (BN hariç)
    for layer in base.layers:
        if not isinstance(layer, tf.keras.layers.BatchNormalization):
            layer.trainable = False

    x = base(x)
    return models.Model(inp, x, name=name)


# --- Ana Model ---
def build_model():
    # Girişler
    art_input   = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3), name="art_input")
    epi_input   = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3), name="epi_input")
    male_input  = layers.Input(shape=(1,), name="male_input")

    # Backbone'lar
    branch_art = build_backbone("EffNet_Art")
    branch_epi = build_backbone("EffNet_Epi")

    feat_art = branch_art(art_input)
    feat_epi = branch_epi(epi_input)

    # Birleştirme
    fused = layers.Concatenate(name="fusion")(
        [feat_art, feat_epi, male_input]
    )

    # Dense blokları
    x = layers.Dense(512,activation="relu")(fused)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(128,activation="relu",)(x)
    x = layers.Dropout(0.2)(x)

    # Çıkış (0–1 arası)
    out = layers.Dense(1, activation="linear")(x)

    return models.Model(
        inputs=[art_input, epi_input, male_input],
        outputs=out
    )


# Modeli oluştur ve özetle
model = build_model()
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ art_input           │ (None, 320, 320,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ epi_input           │ (None, 320, 320,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ EffNet_Art          │ (None, 2048)      │ 23,587,712 │ art_input[0][0]   │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ EffNet_Epi          │ (None, 2048)      │ 23,587,712 │ epi_input[0][0]   │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ male_input          │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fusion              │ (None, 4097)      │          0 │ EffNet_Art[0][0], │
# │ (Concatenate)       │                   │            │ EffNet_Epi[0][0], │
# │                     │                   │            │ male_input[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │  2,098,176 │ fusion[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │     65,664 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │        129 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 49,339,393 (188.21 MB)
#  Trainable params: 2,270,209 (8.66 MB)
#  Non-trainable params: 47,069,184 (179.55 MB)

# %%
# ===============================
# 4. COMPILE & EĞİTİM
# ===============================

model.compile(
    optimizer=tf.keras.optimizers.AdamW(
        learning_rate=1e-4,
        weight_decay=1e-5
    ),
    loss="mae",
)


# --- Callback'ler ---

#--------İyilişmezse durdur--------
cb_early = EarlyStopping(
    monitor="val_loss",
    patience=20,
    mode="min",
    restore_best_weights=True,
    verbose=1,
)

#-----Öğrenme hızını düşür-----
cb_lr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.6,
    patience=4,
    mode="min",
    min_lr=1e-6,
    verbose=1,
)

# --- MODELİ EĞİT ---
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=[cb_early, cb_lr],
    verbose=1,
)

#----Modeli Kaydet--------
print("\nEğitim tamamlandı.")

model_path = os.path.join(
    MODEL_DIR, "ResNet50.keras"
)

model.save(model_path)

print("Final model kaydedildi:")
print(model_path)
# Out:
# Epoch 1/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 114s 378ms/step - loss: 64.5937 - val_loss: 34.7998 - learning_rate: 1.0000e-04
# Epoch 2/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 32.7065 - val_loss: 28.4489 - learning_rate: 1.0000e-04
# Epoch 3/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 26.7886 - val_loss: 24.6569 - learning_rate: 1.0000e-04
# Epoch 4/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 23.6514 - val_loss: 22.8032 - learning_rate: 1.0000e-04
# Epoch 5/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 22.0281 - val_loss: 21.1179 - learning_rate: 1.0000e-04
# Epoch 6/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 24.2856 - val_loss: 20.0949 - learning_rate: 1.0000e-04
# Epoch 7/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 21.5610 - val_loss: 19.3400 - learning_rate: 1.0000e-04
# Epoch 8/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 20.9514 - val_loss: 17.5409 - learning_rate: 1.0000e-04
# Epoch 9/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 19.9871 - val_loss: 16.2648 - learning_rate: 1.0000e-04
# Epoch 10/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 20.5407 - val_loss: 15.7654 - learning_rate: 1.0000e-04
# Epoch 11/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 18.5082 - val_loss: 16.0788 - learning_rate: 1.0000e-04
# Epoch 12/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 20.6122 - val_loss: 15.4527 - learning_rate: 1.0000e-04
# Epoch 13/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 19.0582 - val_loss: 15.4161 - learning_rate: 1.0000e-04
# Epoch 14/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 17.4860 - val_loss: 15.4296 - learning_rate: 1.0000e-04
# Epoch 15/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 18.5074 - val_loss: 15.4123 - learning_rate: 1.0000e-04
# Epoch 16/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 20.2619 - val_loss: 15.4312 - learning_rate: 1.0000e-04
# Epoch 17/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 19.0595 - val_loss: 15.3126 - learning_rate: 1.0000e-04
# Epoch 18/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 17.6367 - val_loss: 15.4367 - learning_rate: 1.0000e-04
# Epoch 19/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 16.4667 - val_loss: 15.1701 - learning_rate: 1.0000e-04
# Epoch 20/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 17.3737 - val_loss: 15.2634 - learning_rate: 1.0000e-04
# Epoch 21/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 17.9335 - val_loss: 15.0908 - learning_rate: 1.0000e-04
# Epoch 22/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 17.6359 - val_loss: 21.5218 - learning_rate: 1.0000e-04
# Epoch 23/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 18.0288 - val_loss: 15.6920 - learning_rate: 1.0000e-04
# Epoch 24/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 17.3396 - val_loss: 15.1356 - learning_rate: 1.0000e-04
# Epoch 25/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 16.1969
# Epoch 25: ReduceLROnPlateau reducing learning rate to 5.999999848427251e-05.
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 16.2020 - val_loss: 15.8584 - learning_rate: 1.0000e-04
# Epoch 26/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 17.6966 - val_loss: 15.0767 - learning_rate: 6.0000e-05
# Epoch 27/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 17.6564 - val_loss: 15.1756 - learning_rate: 6.0000e-05
# Epoch 28/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 16.5368 - val_loss: 16.4673 - learning_rate: 6.0000e-05
# Epoch 29/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 16.5354 - val_loss: 15.0750 - learning_rate: 6.0000e-05
# Epoch 30/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 16.5710 - val_loss: 14.8298 - learning_rate: 6.0000e-05
# Epoch 31/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 17.2539 - val_loss: 14.8454 - learning_rate: 6.0000e-05
# Epoch 32/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 17.0261 - val_loss: 14.6657 - learning_rate: 6.0000e-05
# Epoch 33/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 14.7635 - val_loss: 14.6553 - learning_rate: 6.0000e-05
# Epoch 34/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 14.0608 - val_loss: 15.6320 - learning_rate: 6.0000e-05
# Epoch 35/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 15.0268 - val_loss: 14.8108 - learning_rate: 6.0000e-05
# Epoch 36/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 16.3524 - val_loss: 15.6539 - learning_rate: 6.0000e-05
# Epoch 37/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 15.2253
# Epoch 37: ReduceLROnPlateau reducing learning rate to 3.599999909056351e-05.
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 15.2365 - val_loss: 14.8423 - learning_rate: 6.0000e-05
# Epoch 38/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 15.3075 - val_loss: 14.6779 - learning_rate: 3.6000e-05
# Epoch 39/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 14.3696 - val_loss: 15.9103 - learning_rate: 3.6000e-05
# Epoch 40/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 14.1027 - val_loss: 14.9703 - learning_rate: 3.6000e-05
# Epoch 41/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 15.9139
# Epoch 41: ReduceLROnPlateau reducing learning rate to 2.1599998581223188e-05.
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 15.9077 - val_loss: 14.8457 - learning_rate: 3.6000e-05
# Epoch 42/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 14.8560 - val_loss: 14.9047 - learning_rate: 2.1600e-05
# Epoch 43/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 14.3077 - val_loss: 14.7035 - learning_rate: 2.1600e-05
# Epoch 44/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 13.7411 - val_loss: 14.9016 - learning_rate: 2.1600e-05
# Epoch 45/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 15.9722
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.2959999367012642e-05.
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 15.9688 - val_loss: 14.7922 - learning_rate: 2.1600e-05
# Epoch 46/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 15.0566 - val_loss: 14.8256 - learning_rate: 1.2960e-05
# Epoch 47/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 13.5496 - val_loss: 14.7142 - learning_rate: 1.2960e-05
# Epoch 48/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 14.9861 - val_loss: 14.7424 - learning_rate: 1.2960e-05
# Epoch 49/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 13.8670
# Epoch 49: ReduceLROnPlateau reducing learning rate to 7.775999620207585e-06.
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 13.8813 - val_loss: 14.7422 - learning_rate: 1.2960e-05
# Epoch 50/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 14.7091 - val_loss: 14.6399 - learning_rate: 7.7760e-06
# Restoring model weights from the end of the best epoch: 50.
#
# Eğitim tamamlandı.
# Final model kaydedildi:
# /content/drive/My Drive/BoneAgeProject/models/bone_age_final_model.keras

# %%
# =========================================================
# 5. INFERENCE & SUNUM (FINAL MODEL - SADECE TAHMİN)
# =========================================================

import os
import cv2
import math
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from tensorflow.keras.models import load_model

from google.colab import drive
drive.mount('/content/drive')

print("🖥️ TEST / SUNUM MODU BAŞLATILDI")

# ------------------ AYARLAR ------------------
IMG_SIZE = 320
BATCH_SIZE = 8
MAX_AGE = 228
PER_PAGE = 4

# ------------------ SABİT DRIVE YOLLARI ------------------
BASE_PROJECT = "/content/drive/My Drive/BoneAgeProject"

MODEL_PATH = os.path.join(
    BASE_PROJECT,
    "models",
    "ResNet50.keras"
)

DATASET_BASE = os.path.join(BASE_PROJECT, "DATASET")

ART_DIR = os.path.join(DATASET_BASE, "Articular_Surface_Test")
EPI_DIR = os.path.join(DATASET_BASE, "Epiphysis_Test")
TEST_CSV = os.path.join(DATASET_BASE, "test.csv")

# ------------------ KONTROLLER ------------------
if not os.path.exists(MODEL_PATH):
    raise RuntimeError(f"Model bulunamadı: {MODEL_PATH}")

if not os.path.exists(TEST_CSV):
    raise RuntimeError("test.csv bulunamadı!")

print("🧠 Model yolu :", MODEL_PATH)
print("📂 Dataset yolu:", DATASET_BASE)

# ------------------ YARDIMCI (MODELLE UYUMLU) ------------------
def load_img(path):
    img = cv2.imread(path)
    if img is None:
        return None
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
    return img.astype(np.float32)

# ------------------ VERİ YÜKLE ------------------
df = pd.read_csv(TEST_CSV)

X_art, X_epi, males, y_true, ids = [], [], [], [], []

for _, row in df.iterrows():
    pid = str(row["id"])

    p_art = os.path.join(ART_DIR, pid + ".png")
    p_epi = os.path.join(EPI_DIR, pid + ".png")

    if not (os.path.exists(p_art) and os.path.exists(p_epi)):
        continue

    img_art = load_img(p_art)
    img_epi = load_img(p_epi)

    if img_art is None or img_epi is None:
        continue

    X_art.append(img_art)
    X_epi.append(img_epi)
    males.append(1.0 if row["male"] else 0.0)
    y_true.append(float(row["boneage"]))
    ids.append(pid)

X_art = np.array(X_art)
X_epi = np.array(X_epi)
males = np.array(males).reshape(-1, 1)
y_true = np.array(y_true)

print(f"✅ Toplam test örneği: {len(y_true)}")

# ------------------ MODEL YÜKLE ------------------
model = load_model(MODEL_PATH, compile=False)
print("🏆 Final model yüklendi")

# ------------------ TAHMİN ------------------
preds = model.predict(
    {
        "art_input": X_art,
        "epi_input": X_epi,
        "male_input": males
    },
    batch_size=BATCH_SIZE,
    verbose=0
).flatten()

pred_ages = preds
errors = np.abs(pred_ages - y_true)
ss_res = np.sum((y_true - pred_ages) ** 2)
ss_tot = np.sum((y_true - np.mean(y_true)) ** 2)
r2 = 1 - (ss_res / ss_tot)
rmse = np.sqrt(np.mean((pred_ages - y_true) ** 2))

# ------------------ ÇİZGİ GRAFİĞİ ------------------
plt.figure(figsize=(12, 5))
x = np.arange(1, len(y_true) + 1)

plt.plot(x, y_true, label="Gerçek Yaş", linewidth=2)
plt.plot(x, pred_ages, label="Tahmini Yaş", linewidth=2)

plt.xlabel("Kişi İndeksi")
plt.ylabel("Yaş (ay)")
plt.title("Gerçek ve Tahmin Edilen Kemik Yaşı (Test Kümesi)")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ------------------ METİNSEL ÖZET ------------------
print("\n📊 ÖZET")
print(f"Test MAE : {errors.mean():.2f} ay")
print(f"Test RMSE: {rmse:.2f}")
print(f"Test R²  : {r2:.2f}\n")
# Out:
# Mounted at /content/drive
# 🖥️ TEST / SUNUM MODU BAŞLATILDI
# 🧠 Model yolu : /content/drive/My Drive/BoneAgeProject/models/ResNet50.keras
# 📂 Dataset yolu: /content/drive/My Drive/BoneAgeProject/DATASET
# ✅ Toplam test örneği: 97
# 🏆 Final model yüklendi
# 📊 ÖZET
# Test MAE : 13.80 ay
# Test RMSE: 17.53
# Test R²  : 0.87
