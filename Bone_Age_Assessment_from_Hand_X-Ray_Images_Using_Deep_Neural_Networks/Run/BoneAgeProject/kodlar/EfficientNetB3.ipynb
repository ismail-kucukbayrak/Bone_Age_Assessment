# %%
# ===============================
# 1. ORTAM & DRIVE AYARLARI
# ===============================

# Temel kütüphaneler
import os
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt

# TensorFlow / Keras
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.applications import EfficientNetB3
from tensorflow.keras.applications.efficientnet import preprocess_input

# Colab Drive
from google.colab import drive

# -------------------------------
# Google Drive bağla
# -------------------------------
drive.mount('/content/drive')

# -------------------------------
# Proje yolları
# -------------------------------
PROJECT_ROOT = "/content/drive/My Drive/BoneAgeProject"
DATASET_DIR  = os.path.join(PROJECT_ROOT, "DATASET")
MODEL_DIR    = os.path.join(PROJECT_ROOT, "models")

# -------------------------------
# Dataset alt klasörleri
# -------------------------------
Articular_Surface_Train = os.path.join(DATASET_DIR, "Articular_Surface_Train")
Articular_Surface_Val   = os.path.join(DATASET_DIR, "Articular_Surface_Val")

Epiphysis_Train = os.path.join(DATASET_DIR, "Epiphysis_Train")
Epiphysis_Val   = os.path.join(DATASET_DIR, "Epiphysis_Val")

train_csv = os.path.join(DATASET_DIR, "train.csv")
val_csv   = os.path.join(DATASET_DIR, "val.csv")

# -------------------------------
# Global sabitler
# -------------------------------
IMG_SIZE   = 320
BATCH_SIZE = 8
MAX_AGE    = 228

# -------------------------------
# Ortam bilgisi (kontrol amaçlı)
# -------------------------------
print("TensorFlow:", tf.__version__)
print("GPU:", tf.config.list_physical_devices("GPU"))
print("Proje dizini:", PROJECT_ROOT)
print("Dataset dizini:", DATASET_DIR)
print("Model kayıt dizini:", MODEL_DIR)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# TensorFlow: 2.19.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Proje dizini: /content/drive/My Drive/BoneAgeProject
# Dataset dizini: /content/drive/My Drive/BoneAgeProject/DATASET
# Model kayıt dizini: /content/drive/My Drive/BoneAgeProject/models

# %%
# ===============================
# 2. VERİ YÜKLEME & tf.data
# ===============================

def load_image(path):
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
    img = img.astype(np.float32)
    return img


def create_dataset(csv_path, art_dir, epi_dir):
    df = pd.read_csv(csv_path)

    X_art, X_epi, males, y = [], [], [], []

    for _, row in df.iterrows():
        _id = str(row["id"])
        boneage = float(row["boneage"])

        art_path = os.path.join(art_dir, _id + ".png")
        epi_path = os.path.join(epi_dir, _id + ".png")

        if not (os.path.exists(art_path) and os.path.exists(epi_path)):
            continue

        X_art.append(load_image(art_path))
        X_epi.append(load_image(epi_path))
        males.append(1.0 if row["male"] else 0.0)
        y.append(boneage)

    return (
        np.array(X_art, dtype=np.float32),
        np.array(X_epi, dtype=np.float32),
        np.array(males, dtype=np.float32).reshape(-1, 1),
        np.array(y, dtype=np.float32),
    )


# -------------------------------
# Datasetleri yükle
# -------------------------------
X_art_train, X_epi_train, male_train, y_train = create_dataset(
    train_csv, Articular_Surface_Train, Epiphysis_Train
)

X_art_val, X_epi_val, male_val, y_val = create_dataset(
    val_csv, Articular_Surface_Val, Epiphysis_Val
)

print("Veriler yüklendi.")


# -------------------------------
# YAŞ NORMALİZASYONU
# -------------------------------
y_train = y_train / MAX_AGE
y_val   = y_val   / MAX_AGE

# -------------------------------
# tf.data Datasetleri
# -------------------------------
train_ds = tf.data.Dataset.from_tensor_slices(
    (
        {
            "art_input": X_art_train,
            "epi_input": X_epi_train,
            "male_input": male_train,
        },
        y_train,
    )
)

val_ds = tf.data.Dataset.from_tensor_slices(
    (
        {
            "art_input": X_art_val,
            "epi_input": X_epi_val,
            "male_input": male_val,
        },
        y_val,
    )
)

train_ds = train_ds.shuffle(1000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
val_ds   = val_ds.shuffle(100).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

print("tf.data pipeline hazır.")
# Out:
# Veriler yüklendi.
# tf.data pipeline hazır.

# %%
# ===============================
# 3. MODEL TANIMI
# ===============================

# --- EfficientNet Backbone ---
def build_backbone(name):
    inp = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = preprocess_input(inp)

    base = EfficientNetB3(
        include_top=False,
        weights="imagenet",
        pooling="avg"
    )

    # 1) Tüm katmanları dondur
    for layer in base.layers:
        layer.trainable = False

    # 2) Son ~20 katmanı (BN hariç) aç
    for layer in base.layers[-20:]:
        if not isinstance(layer, tf.keras.layers.BatchNormalization):
            layer.trainable = True

    x = base(x)
    return models.Model(inp, x, name=name)


# --- Ana Model ---
def build_model():
    # Girişler
    art_input   = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3), name="art_input")
    epi_input   = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3), name="epi_input")
    male_input  = layers.Input(shape=(1,), name="male_input")

    # Backbone'lar
    branch_art = build_backbone("EffNet_Art")
    branch_epi = build_backbone("EffNet_Epi")

    feat_art = branch_art(art_input)
    feat_epi = branch_epi(epi_input)

    # Birleştirme
    fused = layers.Concatenate(name="fusion")(
        [feat_art, feat_epi, male_input]
    )

    # Dense blokları
    x = layers.Dense(512,activation="relu")(fused)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(128,activation="relu",)(x)
    x = layers.Dropout(0.2)(x)

    # Çıkış (0–1 arası)
    out = layers.Dense(1, activation="sigmoid")(x)

    return models.Model(
        inputs=[art_input, epi_input, male_input],
        outputs=out
    )


# Modeli oluştur ve özetle
model = build_model()
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ art_input           │ (None, 320, 320,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ epi_input           │ (None, 320, 320,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ EffNet_Art          │ (None, 1536)      │ 10,783,535 │ art_input[0][0]   │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ EffNet_Epi          │ (None, 1536)      │ 10,783,535 │ epi_input[0][0]   │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ male_input          │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fusion              │ (None, 3073)      │          0 │ EffNet_Art[0][0], │
# │ (Concatenate)       │                   │            │ EffNet_Epi[0][0], │
# │                     │                   │            │ male_input[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │  1,573,888 │ fusion[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │     65,664 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │        129 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 23,206,751 (88.53 MB)
#  Trainable params: 7,289,281 (27.81 MB)
#  Non-trainable params: 15,917,470 (60.72 MB)

# %%
# ===============================
# 4. COMPILE & EĞİTİM
# ===============================

model.compile(
    optimizer=tf.keras.optimizers.AdamW(
        learning_rate=5e-4,
        weight_decay=1e-5
    ),
    loss="mae",
)


# --- Callback'ler ---

#--------İyilişmezse durdur
cb_early = EarlyStopping(
    monitor="val_loss",
    patience=20,
    mode="min",
    restore_best_weights=True,
    verbose=1,
)

#-----Öğrenme hızını düşür-----
cb_lr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.6,
    patience=4,
    mode="min",
    min_lr=1e-6,
    verbose=1,
)

# --- MODELİ EĞİT ---
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=[cb_early, cb_lr],
    verbose=1,
)

#----Modeli Kaydet--------
print("\nEğitim tamamlandı.")

model_path = os.path.join(
    MODEL_DIR, "EfficientNetB3.keras"
)

model.save(model_path)

print("Final model kaydedildi:")
print(model_path)
# Out:
# Epoch 1/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 175s 706ms/step - loss: 0.1553 - val_loss: 0.0868 - learning_rate: 5.0000e-04
# Epoch 2/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.1009 - val_loss: 0.0756 - learning_rate: 5.0000e-04
# Epoch 3/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 0.0837 - val_loss: 0.0740 - learning_rate: 5.0000e-04
# Epoch 4/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 0.0861 - val_loss: 0.0719 - learning_rate: 5.0000e-04
# Epoch 5/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0804 - val_loss: 0.0643 - learning_rate: 5.0000e-04
# Epoch 6/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0780 - val_loss: 0.0835 - learning_rate: 5.0000e-04
# Epoch 7/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0790 - val_loss: 0.0655 - learning_rate: 5.0000e-04
# Epoch 8/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 0.0628 - val_loss: 0.0585 - learning_rate: 5.0000e-04
# Epoch 9/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0698 - val_loss: 0.0694 - learning_rate: 5.0000e-04
# Epoch 10/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0691 - val_loss: 0.0666 - learning_rate: 5.0000e-04
# Epoch 11/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0699 - val_loss: 0.0580 - learning_rate: 5.0000e-04
# Epoch 12/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0590 - val_loss: 0.0608 - learning_rate: 5.0000e-04
# Epoch 13/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0654 - val_loss: 0.0653 - learning_rate: 5.0000e-04
# Epoch 14/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0629 - val_loss: 0.0545 - learning_rate: 5.0000e-04
# Epoch 15/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0574 - val_loss: 0.0592 - learning_rate: 5.0000e-04
# Epoch 16/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0588 - val_loss: 0.0545 - learning_rate: 5.0000e-04
# Epoch 17/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0540 - val_loss: 0.0625 - learning_rate: 5.0000e-04
# Epoch 18/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0623
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0622 - val_loss: 0.0564 - learning_rate: 5.0000e-04
# Epoch 19/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0553 - val_loss: 0.0546 - learning_rate: 3.0000e-04
# Epoch 20/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0533 - val_loss: 0.0568 - learning_rate: 3.0000e-04
# Epoch 21/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0485 - val_loss: 0.0537 - learning_rate: 3.0000e-04
# Epoch 22/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0470 - val_loss: 0.0522 - learning_rate: 3.0000e-04
# Epoch 23/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 0.0483 - val_loss: 0.0488 - learning_rate: 3.0000e-04
# Epoch 24/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0449 - val_loss: 0.0523 - learning_rate: 3.0000e-04
# Epoch 25/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0468 - val_loss: 0.0517 - learning_rate: 3.0000e-04
# Epoch 26/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0400 - val_loss: 0.0562 - learning_rate: 3.0000e-04
# Epoch 27/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0474
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.00018000000854954124.
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0473 - val_loss: 0.0536 - learning_rate: 3.0000e-04
# Epoch 28/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0458 - val_loss: 0.0529 - learning_rate: 1.8000e-04
# Epoch 29/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0396 - val_loss: 0.0539 - learning_rate: 1.8000e-04
# Epoch 30/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0376 - val_loss: 0.0509 - learning_rate: 1.8000e-04
# Epoch 31/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0430
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.00010800000163726508.
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0430 - val_loss: 0.0508 - learning_rate: 1.8000e-04
# Epoch 32/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0403 - val_loss: 0.0509 - learning_rate: 1.0800e-04
# Epoch 33/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0374 - val_loss: 0.0494 - learning_rate: 1.0800e-04
# Epoch 34/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0370 - val_loss: 0.0511 - learning_rate: 1.0800e-04
# Epoch 35/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0367
# Epoch 35: ReduceLROnPlateau reducing learning rate to 6.480000010924413e-05.
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0367 - val_loss: 0.0497 - learning_rate: 1.0800e-04
# Epoch 36/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0351 - val_loss: 0.0493 - learning_rate: 6.4800e-05
# Epoch 37/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0359 - val_loss: 0.0501 - learning_rate: 6.4800e-05
# Epoch 38/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0387 - val_loss: 0.0492 - learning_rate: 6.4800e-05
# Epoch 39/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0381
# Epoch 39: ReduceLROnPlateau reducing learning rate to 3.8879999192431565e-05.
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0380 - val_loss: 0.0494 - learning_rate: 6.4800e-05
# Epoch 40/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0335 - val_loss: 0.0496 - learning_rate: 3.8880e-05
# Epoch 41/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 0.0324 - val_loss: 0.0483 - learning_rate: 3.8880e-05
# Epoch 42/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0361 - val_loss: 0.0490 - learning_rate: 3.8880e-05
# Epoch 43/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0326 - val_loss: 0.0488 - learning_rate: 3.8880e-05
# Epoch 44/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0321 - val_loss: 0.0497 - learning_rate: 3.8880e-05
# Epoch 45/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0325
# Epoch 45: ReduceLROnPlateau reducing learning rate to 2.3327999952016398e-05.
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0325 - val_loss: 0.0487 - learning_rate: 3.8880e-05
# Epoch 46/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0322 - val_loss: 0.0494 - learning_rate: 2.3328e-05
# Epoch 47/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0311 - val_loss: 0.0490 - learning_rate: 2.3328e-05
# Epoch 48/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0308 - val_loss: 0.0488 - learning_rate: 2.3328e-05
# Epoch 49/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0335
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.3996800407767295e-05.
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0335 - val_loss: 0.0490 - learning_rate: 2.3328e-05
# Epoch 50/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0349 - val_loss: 0.0493 - learning_rate: 1.3997e-05
# Restoring model weights from the end of the best epoch: 41.
#
# Eğitim tamamlandı.
# Final model kaydedildi:
# /content/drive/My Drive/BoneAgeProject/models/bone_age_final_model.keras

# %%
# =========================================================
# 5. INFERENCE & SUNUM (FINAL MODEL - SADECE TAHMİN)
# =========================================================

import os
import cv2
import math
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from tensorflow.keras.models import load_model

from google.colab import drive
drive.mount('/content/drive')

print("🖥️ TEST / SUNUM MODU BAŞLATILDI")

# ------------------ AYARLAR ------------------
IMG_SIZE = 320
BATCH_SIZE = 8
MAX_AGE = 228
PER_PAGE = 4

# ------------------ SABİT DRIVE YOLLARI ------------------
BASE_PROJECT = "/content/drive/My Drive/BoneAgeProject"

MODEL_PATH = os.path.join(
    BASE_PROJECT,
    "models",
    "EfficientNetB3.keras"
)

DATASET_BASE = os.path.join(BASE_PROJECT, "DATASET")

ART_DIR = os.path.join(DATASET_BASE, "Articular_Surface_Test")
EPI_DIR = os.path.join(DATASET_BASE, "Epiphysis_Test")
TEST_CSV = os.path.join(DATASET_BASE, "test.csv")

# ------------------ KONTROLLER ------------------
if not os.path.exists(MODEL_PATH):
    raise RuntimeError(f"Model bulunamadı: {MODEL_PATH}")

if not os.path.exists(TEST_CSV):
    raise RuntimeError("test.csv bulunamadı!")

print("🧠 Model yolu :", MODEL_PATH)
print("📂 Dataset yolu:", DATASET_BASE)

# ------------------ YARDIMCI (MODELLE UYUMLU) ------------------
def load_img(path):
    img = cv2.imread(path)
    if img is None:
        return None
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
    return img.astype(np.float32)

# ------------------ VERİ YÜKLE ------------------
df = pd.read_csv(TEST_CSV)

X_art, X_epi, males, y_true, ids = [], [], [], [], []

for _, row in df.iterrows():
    pid = str(row["id"])

    p_art = os.path.join(ART_DIR, pid + ".png")
    p_epi = os.path.join(EPI_DIR, pid + ".png")

    if not (os.path.exists(p_art) and os.path.exists(p_epi)):
        continue

    img_art = load_img(p_art)
    img_epi = load_img(p_epi)

    if img_art is None or img_epi is None:
        continue

    X_art.append(img_art)
    X_epi.append(img_epi)
    males.append(1.0 if row["male"] else 0.0)
    y_true.append(float(row["boneage"]))
    ids.append(pid)

X_art = np.array(X_art)
X_epi = np.array(X_epi)
males = np.array(males).reshape(-1, 1)
y_true = np.array(y_true)

print(f"✅ Toplam test örneği: {len(y_true)}")

# ------------------ MODEL YÜKLE ------------------
model = load_model(MODEL_PATH, compile=False)
print("🏆 Final model yüklendi")

# ------------------ TAHMİN ------------------
preds = model.predict(
    {
        "art_input": X_art,
        "epi_input": X_epi,
        "male_input": males
    },
    batch_size=BATCH_SIZE,
    verbose=0
).flatten()

pred_ages = preds * MAX_AGE
errors = np.abs(pred_ages - y_true)
ss_res = np.sum((y_true - pred_ages) ** 2)
ss_tot = np.sum((y_true - np.mean(y_true)) ** 2)
r2 = 1 - (ss_res / ss_tot)
rmse = np.sqrt(np.mean((pred_ages - y_true) ** 2))

# ------------------ ÇİZGİ GRAFİĞİ ------------------
plt.figure(figsize=(12, 5))
x = np.arange(1, len(y_true) + 1)

plt.plot(x, y_true, label="Gerçek Yaş", linewidth=2)
plt.plot(x, pred_ages, label="Tahmini Yaş", linewidth=2)

plt.xlabel("Kişi İndeksi")
plt.ylabel("Yaş (ay)")
plt.title("Gerçek ve Tahmin Edilen Kemik Yaşı (Test Kümesi)")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ------------------ METİNSEL ÖZET ------------------
print("\n📊 ÖZET")
print(f"Test MAE : {errors.mean():.2f} ay")
print(f"Test RMSE: {rmse:.2f}")
print(f"Test R²  : {r2:.2f}\n")
# Out:
# Mounted at /content/drive
# 🖥️ TEST / SUNUM MODU BAŞLATILDI
# 🧠 Model yolu : /content/drive/My Drive/BoneAgeProject/models/EfficientNetB3.keras
# 📂 Dataset yolu: /content/drive/My Drive/BoneAgeProject/DATASET
# ✅ Toplam test örneği: 97
# 🏆 Final model yüklendi
# 📊 ÖZET
# Test MAE : 11.55 ay
# Test RMSE: 14.70
# Test R²  : 0.91
